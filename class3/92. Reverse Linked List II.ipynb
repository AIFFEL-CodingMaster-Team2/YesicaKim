# %% [markdown]
# ### 92. Reverse Linked List II
#
# Reverse a linked list from position m to n. Do it in one-pass.
#
# Note: 1 ≤ m ≤ n ≤ length of list.
#
# #### Example:
# ```
# Input: 1->2->3->4->5->NULL, m = 2, n = 4
# Output: 1->4->3->2->5->NULL
# ```

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def reverseBetween(self, head: ListNode, m: int, n: int) -> ListNode:
        dummy=ListNode(0)
        dummy.next=head

        cur, prev = head, dummy
        for i in range(1,m):
            cur=cur.next
            prev=prev.next

        for i in range(m,n):
            temp=cur.next
            cur.next=temp.next
            temp.next=prev.next
            prev.next=temp

        return dummy.next

# %%
class Solution:
    def reverseBetween(self, head: ListNode, m: int, n: int) -> ListNode:
        if not head or m == n:
            return head
        
        dummy=ListNode(0)
        dummy.next=head
        
        start, end = head, dummy
        
        for _ in range(m - 1):
            start = start.next
            end = end.next

        for _ in range(n - m):
            tmp = start.next
            start.next = tmp.next
            tmp.next = end.next
            end.next = tmp
            
        return dummy.next

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def reverseBetween(self, head: ListNode, m: int, n: int) -> ListNode:
        
        ## do it again.
        
        if not head:
            return None
        
        curr, pre = head, None
        while m>1:
            pre = curr
            curr = curr.next
            m -= 1
            n -= 1
            
        pre_tail = pre
        tail = curr
        while n:
            tmp = curr.next
            curr.next = pre
            pre = curr
            curr = tmp
            n -= 1
        if pre_tail:
            pre_tail.next = pre
        else:
            head = pre
        tail.next = curr
        return head

# %%
class Solution:
    def reverseBetween(self, head: ListNode, m: int, n: int) -> ListNode:
        
        if not head or m == n: 
            return head
        
        p = dummy = ListNode(None)
        p.next = curr = head
        
        for i in range(m-1): 
            p = p.next
            
        t = p.next
        #print(p.val, t.val)
        for i in range(n-m):
            p.next, p.next.next, t.next = t.next, p.next, t.next.next
            '''
            while curr:
                print(curr.val, end = " ")
                curr = curr.next
            print()
            curr = head
            '''
            
        return dummy.next

# %%
class Solution:
    def reverseBetween(self, head: ListNode, m: int, n: int) -> ListNode:
        if not head or m == n:
            return head
        root = start = ListNode(None)
        root.next = head
        print("start : ", start, "\n  root : ", root, "\n")
        for _ in range(m - 1):
            #print("<1st loop> start : ", start, "\n\troot : ", root)
            start = start.next
            print("start : ", start)
        print("--------------------------------------------")
        end = start.next
        for _ in range(n - m):
            #print("<2nd loop> start : ", start, "\n\troot : ", root)
            tmp, start.next, end.next = start.next, end.next, end.next.next
            start.next.next = tmp
            print("start : ", start, "\n  start.next : ", start.next, "\n  end.next : ",end.next, "\n  root : ", root, "\n")
            print("=============================================================")
        print("root.next : ", root.next)
        return

# %%
class Solution:
    def reverseBetween(self, head: ListNode, m: int, n: int) -> ListNode:
        if not head or m == n:
            return head
        
        dummy=ListNode(0)
        dummy.next=head
        
        start, end = head, dummy
        print("\n 1. start = head : ", start, "\n  end = dummy: ", end, "\n")
        for _ in range(m - 1):
            start = start.next
            end = end.next
            print("\n 2. start = start.next : ", start, "\n  end = end.next : ", end, "\n")

        for _ in range(n - m):
            tmp = start.next
            print("\n 3. tmp = start.next : ", tmp)
            start.next = tmp.next
            print("\n 4. start.next = tmp.next : ", start.next)
            tmp.next = end.next
            print("\n 5. tmp.next = end.next : ", tmp.next)
            end.next = tmp
            print("\n 6. end.next = tmp", end.next)
            print("\n 7. start : ", start, "\n  end : ", end, "\n tmp : ", tmp, "\n dummy.next : ", dummy.next)
            
        return dummy.next

# %%
class Solution:
    def reverseBetween(self, head: ListNode, m: int, n: int) -> ListNode:
        if not head or m == n:
            return head
        
        dummy=ListNode(0)
        dummy.next=head
        
        start, end = head, dummy
        
        for _ in range(m - 1):
            start = start.next
            end = end.next

        for _ in range(n - m):
            tmp = start.next
            start.next = tmp.next
            tmp.next = end.next
            end.next = tmp
            
        return dummy.next

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
def print_ll(head):
    while head != None:
        print(head.val, end =" ")
        head = head.next
    print()
def reverse_ll(head):
    node = head.next
    rev = ListNode(val=head.val, next=None)
    while node != None:
        rev = ListNode(val=node.val, next=rev)
        node = node.next
    return rev
class Solution:
    def reverseBetween(self, head: ListNode, m: int, n: int) -> ListNode:
        if m == n:
            return head
        cursor = head
        before_m = None
        mth_node = None
        after_m = None
        before_n = None
        nth_node = None
        after_n = None
        idx = 1
        while cursor != None:
            if idx + 1 == m:
                before_m = cursor
                mth_node = cursor.next
                after_m = cursor.next.next
            elif idx == 1 and m == 1:
                mth_node = cursor
                after_m = cursor.next
            if idx + 1 == n:
                before_n = cursor
                nth_node = cursor.next
                after_n = cursor.next.next
                break
            cursor = cursor.next
            idx +=1
        print("after_n : ", end="")
        print_ll(after_n)
        new_head = mth_node
        new_cursor = mth_node
        while new_cursor != None:
            if new_cursor == nth_node:
                new_cursor.next = None
                break
            new_cursor = new_cursor.next
        rev = reverse_ll(new_head)
        print("rev : ", end="")
        print_ll(rev)
        if m != 1:
            before_m.next = rev
        else:
            head = rev
        rev_cursor = rev
        while rev_cursor != None:
            if rev_cursor.next == None:
                rev_cursor.next = after_n
                break
            rev_cursor = rev_cursor.next
        print("starts with : ", end="")
        print_ll(head)
        print("-----")
        return head
